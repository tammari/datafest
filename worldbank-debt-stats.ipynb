# %% [markdown]
# # Vizualizing BigQuery data in a Jupyter notebook
#
# [BigQuery](https://cloud.google.com/bigquery/docs/) is a petabyte-scale analytics data warehouse that you can use to run SQL queries over vast amounts of data in near realtime.
#
# [Google Datasets](https://console.cloud.google.com/marketplace/browse?filter=solution-type:dataset) as of December 11, contains 207 ranging from income by Country, numerous Covid collections, climate, and global health view from The World Bank
#
# Data visualization tools can help you make sense of your BigQuery data and help you analyze the data interactively. You can use visualization tools to help you identify trends, respond to them, and make predictions using your data. In this tutorial, you use the BigQuery Python client library and pandas in a Jupyter notebook to visualize data in the BigQuery natality sample table.

# %%
from google.cloud import bigquery
import pandas

# %%
# %%bigquery
# select * from `bigquery-public-data.covid19_nyt.us_counties`
# order by date DESC, confirmed_cases DESC
# limit 20
# Out:
#           date          county    state_name county_fips_code  \
# 0   2020-12-13     Los Angeles    California            06037
# 1   2020-12-13   New York City      New York             None
# 2   2020-12-13            Cook      Illinois            17031
# 3   2020-12-13      Miami-Dade       Florida            12086
# 4   2020-12-13        Maricopa       Arizona            04013
# 5   2020-12-13          Harris         Texas            48201
# 6   2020-12-13          Dallas         Texas            48113
# 7   2020-12-13           Clark        Nevada            32003
# 8   2020-12-13  San Bernardino    California            06071
# 9   2020-12-13         Broward       Florida            12011
# 10  2020-12-13         Tarrant         Texas            48439
# 11  2020-12-13       Riverside    California            06065
# 12  2020-12-13       San Diego    California            06073
# 13  2020-12-13          Orange    California            06059
# ...

# %% [markdown]
# # Trinette's Wish List
#
# [GDELT 2.0 Event Database](https://console.cloud.google.com/marketplace/product/the-gdelt-project/gdelt-2-events)  is a global catalog of worldwide activities (“events”) in over 300 categories from protests and military attacks to peace appeals and diplomatic exchanges. Each event record details 58 fields capturing many different attributes of the event. The GDELT 2.0 Event Database currently runs from February 2015 to present, updated every 15 minutes and is comprised of 326 million mentions of 103 million distinct events as of February 19, 2016. This dataset uses machine translation coverage of all monitored content in 65 core languages, with a sample of an additional 35 languages hand translated.
# AND 3.0 is Coming Soon!
#
# [Google BigQuery + GDELT](https://www.gdeltproject.org/data.html#googlebigquery) all GDELT datasets are available in Google BigQuery, with live datasets updated every 15 minutes.
#
# [GDELT demos](https://blog.gdeltproject.org/a-compilation-of-gdelt-bigquery-demos/) Get lost in the demos - many are very dated ... but just look at the things you can do - the questions you can think of with all this translated data.
# ???What ethics are being applied to all this public information collected around the world --- every 15 minutes. ????
#
# [simple network visualizations](http://blog.gdeltproject.org/getting-started-with-gdelt-google-cloud-datalab-simple-network-visualizations/) Jupyter notebook -- the syntax is dated especially if you use Google JupyterLab to interface with BigQuery.
#
# [Research Checklists](https://dimewiki.worldbank.org/wiki/Check_Lists) Do you remember every step of the validation and verification process when preparing data or the timing and flow of questions? These quick reference checklists help with ticking off the boxes before finalizing a visualization or submitting your table to the research team.
